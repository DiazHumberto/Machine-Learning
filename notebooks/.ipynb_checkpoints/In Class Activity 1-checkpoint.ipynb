# %% [markdown]
# ## Exercise 1: Learning Basics of Gradient Descent
# This exercise provides a comprehensive introduction to gradient descent, combining theoretical concepts with practical implementation and visualization.
#
# **Objective**
#
# The goal of this lab exercise is to understand the fundamentals of gradient descent, a key optimization algorithm used in machine learning. You will learn how to implement gradient descent from scratch and visualize the optimization process.
#
# **Prerequisites**
# - Basic knowledge of Python programming
# - Basic understanding of linear regression
# - Familiarity with numpy and matplotlib libraries

# %% [markdown]
# #### Part 1: Understanding the Theory
# **Introduction to Gradient Descent**
#
# Gradient descent is an optimization algorithm used to minimize the cost function in various machine learning algorithms. It iteratively adjusts the model parameters in the opposite direction of the gradient of the cost function with respect to the parameters.
#
# **Key Concepts**
# - Cost Function (Loss Function): Measures how well the model's predictions match the actual data. In linear regression, it is often the Mean Squared Error (MSE).
# - Gradient: The vector of partial derivatives of the cost function with respect to the model parameters.
# - Learning Rate: A hyperparameter that controls the step size of each update in the parameter space.

# %% [markdown]
# #### Part 2: Implementing Gradient Descent
# *Step 1: Generate Synthetic Data*

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Set random seed for reproducibility
np.random.seed(0)

# Generate synthetic dataset
X = 2 * np.random.rand(100, 1)
true_w0 = np.random.randn()
true_w1 = np.random.randn()
y = true_w0 + true_w1 * X + 0.25 * np.random.randn(100, 1)  # Reduced noise

# Add a bias term (column of ones) to the input data
X_b = np.c_[np.ones((100, 1)), X]

# Plot the synthetic data
plt.figure(figsize=(10, 5))
plt.scatter(X, y, label='Data')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Synthetic Dataset')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# *Step 2: Define the Loss Function and Gradient*

# %%
# Define the loss function (mean squared error)
def loss_function(w, X_b, y):
    m = len(y)
    predictions = X_b.dot(w)
    return (1 / (2 * m)) * np.sum((predictions - y) ** 2)

# Define the gradient of the loss function
def gradient(w, X_b, y):
    m = len(y)
    predictions = X_b.dot(w)
    return (1 / m) * X_b.T.dot(predictions - y)

# %% [markdown]
# *Step 3: Implement Gradient Descent*

# %%
# Gradient descent parameters
learning_rate = 0.1
num_iterations = 300

# Initialize weights within a reasonable range
w = np.random.randn(2, 1)*2  # Starting point
w_history = [w.copy()]  # To store the history of weight values
loss_history = [loss_function(w, X_b, y)]  # To store the history of loss values

# Gradient descent loop
for i in range(num_iterations):
    grad = gradient(w, X_b, y)
    w = w - learning_rate * grad
    w_history.append(w.copy())
    loss_history.append(loss_function(w, X_b, y))

# Convert history lists to arrays for easier plotting
w_history = np.array(w_history)
loss_history = np.array(loss_history)

print(loss_history.shape)
w_history.shape
# Out:
# (301,)
# (301, 2, 1)

# %%
# Gradient descent parameters
learning_rate = 0.5
num_iterations = 100

# Initialize weights within a reasonable range
w = np.random.randn(2, 1)*2  # Starting point
w_history = [w.copy()]  # To store the history of weight values
loss_history = [loss_function(w, X_b, y)]  # To store the history of loss values

# Gradient descent loop
for i in range(num_iterations):
    grad = gradient(w, X_b, y)
    w = w - learning_rate * grad
    w_history.append(w.copy())
    loss_history.append(loss_function(w, X_b, y))

# Convert history lists to arrays for easier plotting
w_history = np.array(w_history)
loss_history = np.array(loss_history)

print(loss_history.shape)
w_history.shape
# Out:
# (101,)
# (101, 2, 1)

# %% [markdown]
# #### Part 3: Visualizing the Results
# *Step 4: Plot the Loss Over Iterations*

# %%
# Plot the loss over iterations
plt.figure(figsize=(10, 5))
plt.plot(range(num_iterations + 1), loss_history, label='Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# *Step 5: Plot the Dataset and the Fitted Line*

# %%
# Plot the dataset and the fitted line
plt.figure(figsize=(10, 5))
plt.scatter(X, y, label='Data')
plt.plot(X, X_b.dot(w), color='red', label='Fitted line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# *Step 6:* Visualize the Loss Function Surface and Gradient Descent Path

# %%
# 3D plot of the loss function surface and gradient descent path
fig = plt.figure(figsize=(14, 6))

# Loss function surface plot
ax1 = fig.add_subplot(121, projection='3d')
w0_values = np.linspace(np.min(w_history[:, 0]) - 1, np.max(w_history[:, 0]) + 1, 100)
w1_values = np.linspace(np.min(w_history[:, 1]) - 1, np.max(w_history[:, 1]) + 1, 100)
W0, W1 = np.meshgrid(w0_values, w1_values)
Z = np.array([[loss_function(np.array([[w0], [w1]]), X_b, y) for w0 in w0_values] for w1 in w1_values])
ax1.plot_surface(W0, W1, Z, alpha=0.6, cmap='viridis')

# Gradient descent path
ax1.plot(w_history[:, 0], w_history[:, 1], loss_history, color='red', marker='.', label='Gradient Descent Path')
ax1.set_xlabel('w0')
ax1.set_ylabel('w1')
ax1.set_zlabel('Loss')
ax1.set_title('Gradient Descent on Loss Function')
ax1.legend()

# 2D contour plot
ax2 = fig.add_subplot(122)
contour = ax2.contour(W0, W1, Z, levels=50, cmap='viridis')
ax2.plot(w_history[:, 0], w_history[:, 1], color='red', marker='.', label='Gradient Descent Path')
ax2.set_xlabel('w0')
ax2.set_ylabel('w1')
ax2.set_title('2D Projection of Gradient Descent')
ax2.legend()
plt.colorbar(contour, ax=ax2, shrink=0.8)

plt.show()

# %%
# Print the final value of weights and the corresponding loss
print(f"Final weights: {w.ravel()}")
print(f"Final loss: {loss_function(w, X_b, y)}")
# Out:
# Final weights: [-1.11386218  0.89799697]
# Final loss: 0.031174680080091832

# %% [markdown]
# #### Conclusion
# In this lab exercise, you learned the basics of gradient descent by:
# - Generating a synthetic dataset.
# - Defining the loss function and gradient.
# - Implementing gradient descent from scratch.
# - Visualizing the optimization process through loss plots and fitted line plots.
#
# Feel free to experiment with different learning rates and initial weight values to see how they affect the convergence of the algorithm.
